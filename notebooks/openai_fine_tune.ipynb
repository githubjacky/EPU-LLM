# %%
import os 
os.chdir('..')

# %%
import openai
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
print(openai.api_key)
# Out:
# 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

# %%
openai.FineTuningJob.list()
# Out:
# <OpenAIObject list at 0x10d119010> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-SkP87NpUfW0XNtTuBJDIlHDS",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1697717943,
#       "finished_at": null,
#       "fine_tuned_model": null,
#       "organization_id": "org-LeEyiGplpRwbkPC9U1VakaXH",
#       "result_files": [],
#       "status": "queued",
#       "validation_file": null,
#       "training_file": "file-TQk4qCcScV91J56ub0GoJ0Tn",
#       "hyperparameters": {
#         "n_epochs": 30
#       },
#       "trained_tokens": null,
#       "error": null
#     },
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-8xWcPTwunP0p2GECyEzUoG4u",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1697182836,
#       "finished_at": null,
#       "fine_tuned_model": null,
#       "organization_id": "org-LeEyiGplpRwbkPC9U1VakaXH",
#       "result_files": [],
#       "status": "cancelled",
# ...

# %%
id = openai.FineTuningJob.list().get('data')[0].get('id')
for job in openai.FineTuningJob.list().get('data'):
    if job.get('status') == "running":
        id = job.get('id')
print(f"job id: {id}")
# Out:
# job id: ftjob-SkP87NpUfW0XNtTuBJDIlHDS

# %%
openai.FineTuningJob.retrieve(id)
# openai.FineTuningJob.retrieve('ftjob-4Kj5LtDVD5rSt2AyaDiRhNU8')
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-SkP87NpUfW0XNtTuBJDIlHDS at 0x107802630> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-SkP87NpUfW0XNtTuBJDIlHDS",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1697717943,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-LeEyiGplpRwbkPC9U1VakaXH",
#   "result_files": [],
#   "status": "queued",
#   "validation_file": null,
#   "training_file": "file-TQk4qCcScV91J56ub0GoJ0Tn",
#   "hyperparameters": {
#     "n_epochs": 30
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
openai.FineTuningJob.list_events(id = id, limit = 1)
# Out:
# <OpenAIObject list at 0x10d11aff0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job.event",
#       "id": "ftevent-8U1hnx7PDfXZSa81CrHFHxY8",
#       "created_at": 1697717946,
#       "level": "info",
#       "message": "Files validated, moving job to queued state",
#       "data": {},
#       "type": "message"
#     }
#   ],
#   "has_more": true
# }

# %%
OpenAIObject list at 0x11574x3cb0> JSON: {
  "object": "list",
  "data": [
    {
      "object": "fine_tuning.job.event",
      "id": "ftevent-nwttjsjzG170W5DlU4lm4C26",
      "created_at": 1697716743,
      "level": "info",
      "message": "Files validated, moving job to queued state",
      "data": {},
      "type": "message"
    }
  ],
  "has_more": true
}

# %%
openai.FineTuningJob.list_events(id = id, limit = 1).get('data')[0].get('message')
# openai.FineTuningJob.list_events(id = 'ftjob-ACfSfyCAWCNevwAmbH7fEmgA', limit = 1)
# Out:
# 'Files validated, moving job to queued state'

# %%
openai.FineTuningJob.list()
# Out:
# <OpenAIObject list at 0x10d5028d0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-tKrZz54QjxJW9z8aOpMJhia6",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1697129639,
#       "finished_at": 1697166696,
#       "fine_tuned_model": null,
#       "organization_id": "org-LeEyiGplpRwbkPC9U1VakaXH",
#       "result_files": [],
#       "status": "failed",
#       "validation_file": null,
#       "training_file": "file-fSpbFHPfAAdJ2Ff1mY1AiHor",
#       "hyperparameters": {
#         "n_epochs": 3
#       },
#       "trained_tokens": null,
#       "error": {
#         "code": "server_error",
#         "param": null,
#         "message": "The job failed due to an internal error"
#       }
#     },
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-hhOgV53aIfj1ofOKzv8LZsUP",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1696650894,
#       "finished_at": 1696654743,
# ...
